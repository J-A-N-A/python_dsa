# %% [markdown]
# <a href="https://colab.research.google.com/github/J-A-N-A/python_dsa/blob/main/3_Divide_and_conquer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**DIVIDE AND CONQUER**
# Notes to remember 📝:
#
#
#
# ﻿﻿﻿﻿﻿Divide and conquer is based on multi-branched recursion. The basic idea behind this design paradigm is:
#
#
#
# Divide: If the problem is small, then solve it directly. Otherwise, divide the problem into smaller subsets of the same problem. Divide until the small subset becomes simple enough to solve directly.
# Conquer: Conquer the smaller subsets by solving them recursively.
# Combine: Take the solutions of the sub-problems and merge them to get a solution to the original problem.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ﻿﻿﻿﻿﻿Divide and conquer is based on multi-branched recursion. The basic idea behind this design paradigm is:<br>
#
#
#
# **Divide**: If the problem is small, then solve it directly. Otherwise, divide the problem into smaller subsets of the same problem. Divide until the small subset becomes simple enough to solve directly.<br>
# **Conquer**: Conquer the smaller subsets by solving them recursively. <br>
# **Combine**: Take the solutions of the sub-problems and merge them to get a solution to the original problem.

# %%
#EXAMPLE CODE TO FIND POWER OF A NUMBER USING DIVIDE AND CONQUER APPROACH 
#time complexity o(b)
def power(a,b):
  if(b==0):
  	return 1
  elif(int(b % 2) == 0):                             #CHECK IF IT A EVEN POWER 
    return (power(a, int(b/2)) * power(a, int(b / 2)))  #IF EVEN POWER SPLIT IT BY 2
  else:                                                 
    return (a * power(a ,int(b/2)) * power(a, int(b/2))) #ELSE IF IT IS ODD DIVIDE IT INTO 2 AND MULTIPLY WITH a itself
#driver code
a=2
b=4
print(power(a,b))
# Out:
# 16

# %% [markdown]
# ##USING DYNAMIC APPROACH TO SOLVE THE SAME PROBLEM
# time complexity = o(log(b)

# %%
#EXAMPLE CODE TO FIND POWER OF A NUMBER USING DIVIDE AND CONQUER APPROACH + DYNAMIC PROGRAMMING 
def power(a,b):
  temp=0
  if(b==0):
  	return 1
  temp= power(a,(b//2)) #TEMPORARY VARIABLE STORES THE
  if(int(b % 2) == 0):  #CHECK IF IT A EVEN POWER 
    return (temp * temp)  #IF EVEN POWER SPLIT IT BY 2
  else:                                                 
    return (a * temp * temp) #ELSE IF IT IS ODD DIVIDE IT INTO 2 AND MULTIPLY WITH a itself
#driver code
a=2
b=4
print(power(a,b))
# Out:
# 16
